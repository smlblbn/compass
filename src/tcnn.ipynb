# %%
import pandas as pd
import numpy as np

with open('../data/general/matches_2017-2018.json') as rounds_json:
	rounds = pd.read_json(rounds_json)

print(rounds)
rounds = np.asarray(rounds)
print(rounds[:,11])
# Out:
#      attendance awayForm  awayId  awayScore  awayScoreHT  \
# 0             0              129          0            0
# 1             0               90          3            0
# 2             0                3          2            0
# 3             0            20004          1            0
# 4             0               21          0            0
# 5             0               93          1            0
# 6             0               74          1            0
# 7             0              101          1            0
# 8             0               13          2            0
# 9             0               42          0            0
# 10            0               71          2            0
# 11            0              105          0            0
# 12            0               82          3            0
# 13            0               11          1            0
# 14            0               86          1            0
# ...
